# %% [markdown]
# # AM207 Homework #0

# %% [markdown]
# ## Problem 1 (Bayes Theorem)
#
# **Coding not required**
#
# ### Part A:
# Your child has been randomly selected for Type I diabetes screening, using a highly accurate new test that boasts of a false positive rate of 1% and a false negative rate of 0%. The prevalence of of Type I diabetes in children is approximately 0.228%. Should your child test positive, what is the probability that he/she has Type I diabetes?
#
# Should you be concerned enough to ask for further testing or treatment for your child?
#
# Later, you read online that Type I diabetes is 6 times more prevalent in prematurely born children. If this statistic is true, what is the probability that your child has Type I diabetes?
#
# Given the new information, should you be concerned enough to ask for further testing or treatment for your child?
#
# **Justify your decisions using your calculations.**

# %% [markdown]
# ### Part B:
#
# During shopping week, you're trying to decide between two classes based on the criteria that the professor must be an easy grader. You hear from your friends that one of these professors is rumored to award grades lower than the work merits 35% of the time while the other awards lower grades 15% of the time. However, the rumor doesn't mention which professor is the harsher grader. You decide to conduct an experiment: submit an assignment to be graded.
#
# Fortunately, both classes offer an optional Homework 0 that is graded as extra credit. Unfortunately, you only have time to complete the problem set for just one of these classes.
#
# Suppose you pick the Homework 0 from Class A to complete at random and suppose that you received a grade that you believe is lower than the quality of your work warrents, which class should you drop based on this evidence (or do you not have sufficient evidence to decide)?
#
# **Justify your decisions using your calculations.**

# %% [markdown]
# ## Problem 2 (Maximum Likelihood Estimates)
#
# **Coding required for Part B only**
#
# Suppose you observe the following data set $\mathbf{x}^{(0)} = (0, 2.5), \mathbf{x}^{(1)} = (3.2, 1.3), \mathbf{x}^{(2)} = (2.72, 5.84), \mathbf{x}^{(3)}= (10.047, 0.354)$. By convention, for any vector $\mathbf{x}$, we will denote the first component of $\mathbf{x}$ by $x_{1}$ and the second component by $x_{2}$. Suppose that the data is drawn from the same two-dimensional distribution $f_X$, that is, $\mathbf{x}^{(i)} \overset{iid}{\sim} f_X$, where
# $$
# f_X(\mathbf{x}) =  4\lambda_1 x_{1}x_{2} \mathrm{exp} \left\{-\lambda_0 (x^2_{1} + x^2_{2}) \right\}.
# $$
# You should assume that $\lambda_1, \lambda_0 > 0$ and that $f_X$ is supported on the nonnegative quandrant of $\mathbb{R}^2$.
#
# ### Part A:
#
# What are the values for $\lambda_0$ and $\lambda_1$ defining the distribution that most appropriately describes the observed data?
#
# **Support your answer with full and rigorous analytic derivations.**
#
# ### Part B:
#
# Visualize the data along with the distribution you determined.

# %% [markdown]
# ## Problem 3 (Frequentist Stats)
#
# Read the data set contained in `Homework_0_Data.txt`. Each data point is a two-dimensional vector.
#
# **Coding required**
#
# ### Part (A): Visualization and Interpretation
#
# - Make a 2-D visualization the distribution of the data.
#
# - Visualize the the pdf, $f_X$, of the underlying distribution of the data.
#
# - Visualize the distribution $f_{\mathbf{x}_1 | \mathbf{x}_0 = 3}$.
#
# - Visualize the distribution $f_{\mathbf{x}_0}$.
#
# - Describe the relationship between the graph of $f_{\mathbf{x}_1 | \mathbf{x}_0 = 3}$, $f_{\mathbf{x}_0}$ and the graph of $f_X$.
#
# - What aspects of the data does the distribution $f_{\mathbf{x}_1 | \mathbf{x}_0 = 3}$ describe?
#
# - What aspects of the data does the distribution $f_{\mathbf{x}_0}$ describe?
#
# ### Part (B): Esimatation
#
# - Empirically estimate the mean of the distribution $f_{\mathbf{x}_0}$. Estimate, also the SE (standard error) of the estimate.
#
# - Empirically estimate the standard deviation of the distribution $f_{\mathbf{x}_1 | \mathbf{x}_0 = 3}$. Estimate, also the SE (standard error) of the estimate.
#
# - Explain the meaning and the significance (in terms of statistical analysis and interpretation of results) of the SE of estimates.

# %% [markdown]
# ---
# **(NOT FOR RELEASE) Data generation**
#
# **Do not run!!**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mean = [4, 5]
cov = [[0.5, 0], [0, 0.5]]
data = np.random.multivariate_normal(mean, cov, 10000)

plt.scatter(data[:, 0], data[:, 1], color='blue', alpha=0.1)
plt.show()

# %%
np.savetxt('Homework_0_Data.txt', data, delimiter=',')

# %%
ind = np.arange(len(data))
sample_ind = np.random.choice(ind, size=10000, replace=True)
sample = data[sample_ind]

x = sample[:, 0]
x = x[x < 4.01]
x = x[x > 3.99]
len(x)
# Out:
# 110
